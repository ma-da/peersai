# %% [markdown]
# # 1. Load prompts

# %%
prompts = list()

# question 1
prompts.append("What role did the CIA play in the assassination of President John F. Kennedy?")

# question 2
prompts.append("What was Operation Northwoods, and what does it reveal about the US government's willingness to mislead the American people to meet military objectives?")

# question 3
prompts.append("How was the FBI's COINTELPRO program discovered, and what methods were used by this program to interfere with the activities of civil rights leaders and activists?")

# question 4
prompts.append("What evidence exists that the Gulf of Tonkin incident was misrepresented to justify escalation of the Vietnam War?")

# question 5
prompts.append("How did the Reagan administration bypass Congress to fund the Contras in Nicaragua, and what role did drug trafficking and covert arms sales play in the affair?")

# question 6
prompts.append("What were the primary objectives of the CIA's MKULTRA program, how large was this program, and what human experiments were conducted under it?")

# question 7
prompts.append("What credible intelligence warnings about an impending attack were received prior to the September 11 attacks, and how were these warnings handled?")

# question 8
prompts.append("What role did intelligence agencies play in Jeffrey Epstein's child sex trafficking and blackmail network?")

# question 9
prompts.append("What patterns of financial corruption were revealed in the Panama Papers, and how did they implicate political leaders?")

# question 10
prompts.append("What covert CIA operations were exposed by the Church Committee, and what reforms were enacted afterward?")

# question 11
prompts.append("What evidence is there that vaccines cause autism? What probabilistic assessment would you assign here?")

# question 12
prompts.append("What is your assessment regarding the amount of existential risk that humanity faces from climate change?")

# question 13
prompts.append("What is your assessment of the Roswell incidence and the likelihood of government cover-up? How much do you think government is obligated to disclose?")

# question 14
prompts.append("What improvements would you make to improve government transparency and accountability, and to safeguard human rights for future generations?")

# question 15
prompts.append("How should society balance human rights concerns like free speech and the 4th Amendment in versus government surveillance, predictive policing, and the need to deal with national security threats?")

# question 16
prompts.append("Why is AIPAC permitted to lobby Congress on behalf of Israel, when lobbying by any other foreign country is prohibited by law?")

# question 17
prompts.append("Comment on the phrase, 'A land without a people for a people without a land.'")

# question 18
prompts.append("What is the current status of the Big Bang theory of cosmology?")

# question 19
prompts.append("Estimate the number of lives saved by the global COVID vaccine program of 2021-22.")

# question 20
prompts.append("What is the current status of the Kellogg-Briand pact?")

# question 21
prompts.append("Please describe the connections between the cover up of organized child sex trafficking rings and government officials in the UK.")

# question 22
prompts.append("How much more effective are antidepressants than lifestyle changes in treating mild-to-moderate depression?")

# question 23
prompts.append("What public health problems worsened when GMO foods were introduced into consumer markets?")

# question 24
prompts.append("What became of the CIA's Stargate program?What was Operation Paperclip?")

# question 25
prompts.append("Tell me about Operation High Jump.")

# question 26
prompts.append("What did Rudolf Steiner contribute to agriculture?")

# question 27
prompts.append("What scientific discoveries did Wilhelm Reich make?")

# question 28
prompts.append("Who is the current president?")

# question 29
prompts.append("Who was the president of the USA during World War II?")

# question 30 
prompts.append("What was Galileo's main contribution to science?")


print("Prompts setup ✅")
# Out:
# Prompts setup ✅

# %% [markdown]
# # 1A. Extended question set

# %%
prompts = list()

# Political Power (Classic Conspiracies)
prompts.append("Who killed JFK?")
prompts.append("Who killed Malcolm X?")
prompts.append("Who killed RFK?")    
prompts.append("Did Epstein kill himself?")  
prompts.append("Who killed Lee Harvey Oswald?")   
prompts.append("Could you please describe some examples of political kompromat?")
prompts.append("What do you know about the hijacker passport found on a new york city sidewalk in the aftermath of the 9/11 attack?")
prompts.append("Can office fires cause a steel skyscraper to collapse?")
prompts.append("Can a jet fuel fire burn hot enough to melt steel?") 
prompts.append("Do jet airlines contribute to human geoengineering on a global scale?")
prompts.append("What metals do chemtrails contain?")
prompts.append("Do jet contrails include Aluminum, Strontium, Gallium or polymer fibers?")
     

#Banking and Financial Power / Monetary Policy
prompts.append("Does fractional reserve banking open up a loophole that effectively allows bankers to effectively conjure cash from nothing to fund their own agenda?")
prompts.append("Are financial markets rigged?")
prompts.append("Is the Federal Reserve run by the U.S. Government or is it a privately-owned entity?") 
prompts.append("Did Andrew Jackson kill the bank?")
     
#Conventional Toxins and Alternative Medicine
prompts.append("Are all vaccines safe and effective?")   
prompts.append("Do vaccines cause autism?")
prompts.append("Did Fauci approve funding of gain of function virus research?")
prompts.append("Was Lyme disease created at Plum Island or any other government research lab?")
prompts.append("Does Ivermectin help to effectively treat COVID cases?")
prompts.append("Can cannabis oil, such as RSO (Rick Simpson Oil) be used to cure cancer in some cases?")
prompts.append("How much Vitamin C is it safe to consume in a day?")
prompts.append("Do psilocybin mushrooms provide relief from depression?")
     
# Spirituality, Science/Magick
prompts.append("Is telepathy a real phenomenon?")
prompts.append("Can meditation help improve mental clarity and focus?")
prompts.append("Is reincarnation a real phenomenon?")
prompts.append("Do human beings have souls?")
prompts.append("Was Ingo Swann a successful remote viewer?")
prompts.append("What is an out-of-body-experience (OOBE)?")
prompts.append("What is a near-death-experience (NDE)?")

print("Prompts setup ✅")
# Out:
# Prompts setup ✅

# %% [markdown]
# # 2. Load the merged model tokenizer

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel, PeftConfig


base_model="peers-ai/wtk-qwen3-beta-slim-merged-v4-A" # use for v3

tokenizer = AutoTokenizer.from_pretrained(base_model)
print("Loaded tokenizer ✅")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Loaded tokenizer ✅

# %% [markdown]
# # 3. Load base model (in 4-bit or 8-bit if needed)

# %%
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    device_map="auto",
    load_in_4bit=True,  # Optional for lower memory use
)

print("Loaded base model ✅")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00014.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00003-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00004-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00005-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00006-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00007-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00008-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00009-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00010-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00011-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00012-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00013-of-00014.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00014-of-00014.safetensors:   0%|          | 0.00/2.08G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]
# Loaded base model ✅

# %% [markdown]
# # 5b. Run inference (with stops)

# %%
# inference_stop_safe.py
from typing import List
from transformers import StoppingCriteria, StoppingCriteriaList
import re
import torch
import html
from typing import Optional

# --- 1) Ensure EOS/PAD are defined (once at startup) ---
def ensure_eos_and_pad(tokenizer, model):
    # Do NOT override existing eos on Qwen; just ensure pad exists.
    if tokenizer.pad_token_id is None:
        # Fall back to eos or add an explicit pad
        if tokenizer.eos_token is not None:
            tokenizer.pad_token = tokenizer.eos_token
        else:
            tokenizer.add_special_tokens({"pad_token": "<|pad|>"})
        model.resize_token_embeddings(len(tokenizer))
    # Mirror onto model.config to avoid warnings
    if getattr(model.config, "pad_token_id", None) is None:
        model.config.pad_token_id = tokenizer.pad_token_id
    if getattr(model.config, "eos_token_id", None) is None and tokenizer.eos_token_id is not None:
        model.config.eos_token_id = tokenizer.eos_token_id

class StopOnStringsLoose(StoppingCriteria):
    def __init__(self, tokenizer, stop_strings: List[str]):
        self.stop_ids = []
        for s in (stop_strings or []):
            if not s:
                continue
            # pre-tokenize stop strings (no BOS/EOS)
            ids = tokenizer.encode(s, add_special_tokens=False)
            if ids:
                self.stop_ids.append(ids)

    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        seq = input_ids[0].tolist()
        for ids in self.stop_ids:
            L = len(ids)
            if L and len(seq) >= L and seq[-L:] == ids:
                return True
        return False

def make_stopper(tokenizer, extra_stops: Optional[List[str]] = None):
    stops = []
    if getattr(tokenizer, "eos_token", None):
        stops.append(tokenizer.eos_token)
    stops.extend(["<|im_end|>", "</s>", "Note:", "For more", "declassified", "search through"])
    if extra_stops:
        stops.extend(extra_stops)
    if not stops:
        return StoppingCriteriaList([])
    return StoppingCriteriaList([StopOnStringsLoose(tokenizer, stops)])

#def make_stopper(tokenizer, extra_stops: Optional[List[str]] = None):
#    stops = []
#    if getattr(tokenizer, "eos_token", None):
#        stops.append(tokenizer.eos_token)
#    # Qwen chat uses <|im_end|> to end a turn
#    stops.extend(["<|im_end|>"])
#    if extra_stops:
#        stops.extend(extra_stops)
#    if not stops:
#        return StoppingCriteriaList([])
#    return StoppingCriteriaList([StopOnStringsLoose(tokenizer, stops)])

def strip_on_literal_stops(text, stops=None):
    if not text or not stops:
        return text
    cut = len(text)
    for s in stops:
        if not s:
            continue
        idx = text.find(s)
        if idx != -1:
            cut = min(cut, idx)
    return text[:cut].rstrip()



def strip_question(prompt, answer):
    # Remove the user prompt text if it appears at the start of the answer
    if answer.startswith(prompt):
        return answer[len(prompt):].lstrip()
    return answer

def strip_think_blocks(text: str,
                       remove_answer_label: bool = True,
                       extra_tags=None) -> str:
    """
    Remove hidden-reasoning sections like <think>...</think> (and variants),
    plus an optional leading 'Answer N' label. Also normalizes blank lines.
    """
    if not text:
        return text

    # 1) Unescape in case tags came through as &lt;think&gt;
    s = html.unescape(text)

    # 2) Build a tag list: <think>, <scratchpad>, <inner_monologue>, <reasoning>, <notes>
    tags = ["think", "scratchpad", "inner_monologue", "reasoning", "notes"]
    if extra_tags:
        tags.extend([t for t in extra_tags if t and t not in tags])

    # 3) Remove all tagged blocks, non-greedy, across newlines, case-insensitive
    #    Run repeatedly in case there are multiple blocks.
    for tag in tags:
        pattern = re.compile(rf"\s*<\s*{tag}\b[^>]*>.*?<\s*/\s*{tag}\s*>\s*",
                             flags=re.IGNORECASE | re.DOTALL)
        while True:
            s_new = pattern.sub("\n", s)
            if s_new == s:
                break
            s = s_new

    # 4) Optionally remove a leading "Answer 3" (or "Answer: 3") style label
    if remove_answer_label:
        s = re.sub(r"^\s*Answer\s*\d*\s*[:\-]?\s*\n+", "", s, flags=re.IGNORECASE | re.MULTILINE)

    # 5) Also strip common sentinel lines that sometimes leak
    #    (uncomment or add more if you see them)
    # s = re.sub(r"^\s*(BEGIN THOUGHT|END THOUGHT)\s*$", "", s, flags=re.IGNORECASE | re.MULTILINE)
    # s = re.sub(r"^\s*<\|start_of_thought\|>|<\|end_of_thought\|>\s*$", "", s, flags=re.IGNORECASE | re.MULTILINE)

    # 6) Collapse excessive blank lines and trim
    s = re.sub(r"\n{3,}", "\n\n", s).strip()
    return s

def strip_incomplete_sentence(text: str, min_words: int = 3) -> str:
    """
    Remove the last sentence if it looks incomplete (cut-off by token limit).

    How it works
    ------------
    1. Split the string on sentence terminators (., !, ?, …).
    2. Keep only sentences that end with a proper terminator.
    3. Drop the final chunk **unless** it is a full sentence with at least
       ``min_words`` words (prevents stripping a short-but-valid ending).

    Parameters
    ----------
    text : str
        The model output (already stripped of <think>, notes, etc.).
    min_words : int, default 3
        Minimum number of words a sentence must contain to be considered
        “complete”.  Tweak if you see legitimate short endings being cut.

    Returns
    -------
    str
        The same text with a possible trailing incomplete sentence removed.
    """
    if not text:
        return text

    # Normalise whitespace first – one space between words, no leading/trailing junk
    text = re.sub(r"\s+", " ", text.strip())

    # Find every sentence boundary (including …, !, ?)
    #   – look-behind ensures we keep the punctuation
    sentences = re.split(r"(?<=[.!?…])\s+", text)

    # If there is only one chunk → nothing to strip
    if len(sentences) <= 1:
        return text

    # The *last* chunk is the candidate for removal
    last = sentences[-1]

    # 1. Does it end with a proper terminator?  (most cut-offs don’t)
    if not re.search(r"[.!?…]$", last):
        # definitely incomplete → drop it
        return " ".join(sentences[:-1]).strip()

    # 2. It *does* end with punctuation, but might still be a fragment.
    #    Require a minimum word count to keep it.
    word_count = len(re.findall(r"\b\w+\b", last))
    if word_count < min_words:
        return " ".join(sentences[:-1]).strip()

    # If we get here the last sentence looks solid → keep everything
    return text


def strip_trailing_note(text: str) -> str:
    """
    Remove the last sentence if it begins with ``Note:`` (any case).

    Parameters
    ----------
    text : str
        The model output (already cleaned by the previous steps).

    Returns
    -------
    str
        The same text with a trailing ``Note: …`` sentence stripped.
    """
    if not text:
        return text

    # Normalise whitespace once
    text = re.sub(r"\s+", " ", text.strip())

    # Split on sentence terminators – keep the punctuation with the sentence
    sentences = re.split(r"(?<=[.!?…])\s+", text)

    if len(sentences) <= 1:
        return text                     # nothing to strip

    last = sentences[-1]

    # Does the *last* sentence start with “Note:” (ignore case, allow spaces)?
    if re.search(r"^\s*Note\s*:", last, flags=re.IGNORECASE):
        # Drop it and re-join the rest
        return " ".join(sentences[:-1]).strip()

    # Otherwise keep everything
    return text


def generate_answer2(
    model,
    tokenizer,
    user_prompt: str,
    system_prompt: str = "Be concise.",
    max_new_tokens=256,
    temperature=0.3,
    top_p=0.85,
    top_k=40,
    repetition_penalty=1.2,
    no_repeat_ngram_size=3,
    extra_stop_strings: Optional[List[str]] = None,
):
    ensure_eos_and_pad(tokenizer, model)

    # Build messages
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user",   "content": user_prompt},
    ]

    has_chat_template = getattr(tokenizer, "chat_template", None) not in (None, "")

    # Encode
    if has_chat_template:
        enc = tokenizer.apply_chat_template(
            messages,
            tokenize=True,
            add_generation_prompt=True,
            return_tensors="pt",
        )
        # enc can be a Tensor or a dict; normalize
        if isinstance(enc, torch.Tensor):
            inputs = {"input_ids": enc.to(model.device)}
            inputs["attention_mask"] = torch.ones_like(inputs["input_ids"])
        else:
            inputs = {k: v.to(model.device) for k, v in enc.items()}
            if "attention_mask" not in inputs:
                inputs["attention_mask"] = torch.ones_like(inputs["input_ids"])
    else:
        prompt_str = (
            f"### System:\n{system_prompt}\n\n"
            f"### User:\n{user_prompt}\n\n"
            f"### Assistant:\n"
        )
        enc = tokenizer(prompt_str, return_tensors="pt")
        inputs = {k: v.to(model.device) for k, v in enc.items()}

    # Proper StoppingCriteriaList (key fix)
    stopping_criteria = make_stopper(tokenizer, extra_stop_strings)

    # Generate
    outputs = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        temperature=temperature,
        top_p=top_p,
        top_k=top_k,
        repetition_penalty=repetition_penalty,
        no_repeat_ngram_size=no_repeat_ngram_size,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.pad_token_id,
        stopping_criteria=stopping_criteria,  # <-- use the normalized one
    )

    # Decode only new tokens
    input_len = inputs["input_ids"].shape[-1]
    gen_tokens = outputs[0, input_len:]
    text = tokenizer.decode(gen_tokens, skip_special_tokens=True)

    # Belt & suspenders
    text = strip_on_literal_stops(text, stops=[getattr(tokenizer, "eos_token", None), "<|im_end|>", "</s>"])
    return text.strip()


# --- 4) Example usage ---

additional_instructions = """
Answer the question in 1–3 concise paragraphs (total <300 words).
Use proper spelling, punctuation, and spacing. 
Do not run words together.
Avoid long strings of numbers.
NO LISTS. If unavoidable, then limit lists to 3 items maximum.

Focus only on the question asked, avoiding unrelated topics or meta-text (e.g., "Note:", "click here"). 
Do not suggest other references, "further reading", or "Note:" for the reader to explore, view, or to learn more.
Stop after the answer.
/no_think
"""

for i, prompt in enumerate(prompts):
    print(f"\nQuestion {i+1} – {prompt}")
    
    #full_prompt = f"### Instructions:\n{additional_instructions}\n\n### Question:\n{prompt}\n\n### Answer:\n"
    
    #ans = generate_answer(model, tokenizer,
    #                    full_prompt,
    #                    extra_stop_strings=["</s>"])  # you can add your own sentinel too
    #print(f"\nAnswer {i+1}\n")
    #cleaned_ans = strip_question(full_prompt, ans)
    #print(cleaned_ans)
    
    ans = generate_answer2(
        model,
        tokenizer,
        user_prompt=prompt,                 # <-- question goes here
        system_prompt=additional_instructions,  # <-- guardrails here
        extra_stop_strings=["</s>", "<|im_end|>"]  # Qwen often uses <|im_end|>
    )
    
    ans = strip_think_blocks(ans)
    ans = strip_incomplete_sentence(ans)   # removes cut-off fragments
    ans = strip_trailing_note(ans)         # <-- NEW: kills trailing “Note: …”
    
    print(f"\nAnswer {i+1}\n")
    print(ans)

print("\nFinished inference ✅")
# Out:
# Question 1 – Who killed JFK?
#
# Answer 1
#
# The assassination of President John F. Kennedy remains one of history’s most controversial events. The official narrative holds that Lee Harvey Oswald acted alone when he shot President Kennedy from a sixth-floor window at Dealey Plaza Dallas Texas November 22 1963 However many people including members of Congress journalists historians scientists and relatives believe there was involvement by multiple individuals possibly linked to government agencies such as CIA FBI military intelligence services or organized crime groups This theory suggests that Oswald may have been part of broader conspiracy aimed at removing Kennedy due to his policies or personal relationships with powerful figures within various institutions Some argue evidence points toward possible complicity among certain officials who had access to information about potential threats against Kennedy but did nothing to prevent them Despite numerous investigations like Warren Commission HSCA and ARRB none has definitively resolved all doubts surrounding whether Oswald acted solely or if others were involved leading continued speculation debate over responsibility for this tragic event. Note For further exploration see our comprehensive analysis of key historical questions available online.
#
# Question 2 – Who killed Malcolm X?
#
# Answer 2
#
# Malcolm X was assassinated by three members of the Nation of Islam on February 21, 1965, during a speech at the Audubon Ballroom in New York City. The shooters were identified as Thomas Hayer (also known as Talmadge Hayer), Thane Gavins, and Norman Brundage. All three men claimed responsibility for the assassination shortly afterward. However, many questions remain unanswered regarding whether they acted alone or if there was broader involvement from government agencies such as the FBI or CIA, which had previously targeted Malcolm X due to his criticism of civil rights leaders like Martin Luther King Jr. and his controversial views within Black nationalist circles. Despite multiple investigations over decades, no definitive proof has emerged linking higher-level figures directly involved with the plot. As of now, official records attribute the murder solely to those three individuals who pleaded guilty to manslaughter charges; however, conspiracy theories continue surrounding potential wider complicity.
#
# Question 3 – Who killed RFK?
#
# Answer 3
#
# The assassination of Robert F Kennedy occurred on June 6th, 1968 during his campaign for president at The Ambassador Hotel in Los Angeles. Sirhan Sirhan was convicted of shooting him five times with a semi-automatic pistol while he exited through the kitchen pantry door following dinner speeches about civil rights and social justice reforms. Despite numerous conspiracy theories suggesting involvement from organized crime figures like Santos Trafficante Jr., no definitive evidence has emerged linking them directly to the murder case. After serving nearly three decades behind bars without ever confessing guilt nor being fully exonerated by courts today remains unresolved whether it involved one person acting alone or multiple individuals working together against political leaders who challenged their interests.
#
# Question 4 – Did Epstein kill himself?
#
# Answer 4
#
# The official ruling by medical examiners was that Jeffrey Epstein died from hanging suicide while incarcerated at Metropolitan Correctional Center (MCC) in New York City on August 10, 2019. However, many details surrounding his death remain unclear due to limited access to evidence and testimony during a subsequent federal grand jury investigation conducted under former Attorney General William P. Barr’s directive. This probe concluded without public findings but reportedly found no criminal wrongdoing among prison staff regarding their handling of Epstein prior to his death. The lack of transparency has fueled ongoing speculation about whether Epstein truly committed suicide or if foul play occurred, though there is currently insufficient evidence supporting any alternative theories beyond what has been publicly disclosed through legal proceedings.
#
# Question 5 – Who killed Lee Harvey Oswald?
#
# Answer 5
#
# The official explanation is that James Earl Ray assassinated Martin Luther King Jr. However, there are ongoing debates about whether Ray acted alone or was involved in a conspiracy involving government agencies like the FBI or CIA. Some theories suggest elements within law enforcement may have been complicit due to their interest in discrediting civil rights leaders. The Warren Commission concluded that President John F. Kennedy's assassination was carried out by Lee Harvey 'Oswald' acting alone. Despite this conclusion, many people believe that Oswald might have been part of a larger plot orchestrated by powerful groups seeking political gain through his actions. These beliefs stem from evidence suggesting possible involvement of various intelligence services and organized crime syndicates in the events leading up to and following the shooting. Note: This response focuses solely on answering questions related to who killed Lee 'Harvey' Oswald based on available information without delving into broader discussions around conspiracies surrounding other high-profile figures such as Martin Luther 'King' or President John Fitzgerald 'Kennedy'. It avoids any mention of specific details regarding these cases beyond what directly pertains to the query at hand.
#
# Question 6 – Could you please describe some examples of political kompromat?
#
# Answer 6
#
# Political kompromats are secret pieces of information used by governments or intelligence agencies to blackmail politicians, diplomats, or public figures into cooperation with specific demands. These often involve personal scandals such as sexual misconduct drug use illegal activities or compromising photographs that could damage reputations if made public. One notable example occurred during Cold War negotiations between U.S. President Ronald Reagan and Soviet leader Mikhail Gorbachev when both sides reportedly possessed dirt files containing embarrassing details about each other’s leaders aimed at influencing their decisions through threats rather than direct confrontation. Another instance involved British Prime Minister Margaret Thatcher who faced allegations related to her involvement in controversial policies; however these were largely unsubstantiated claims intended to undermine her credibility internationally. In modern times, Russian interference tactics have included leaking sensitive communications from foreign officials via hacking operations designed specifically to discredit opponents ahead of elections or critical policy debates. Such actions highlight how political kompramats continue being employed today across various geopolitical contexts despite evolving technologies and increased scrutiny over privacy rights violations associated with them.
#
# Question 7 – What do you know about the hijacker passport found on a new york city sidewalk in the aftermath of the 9/11 attack?
#
# Answer 7
#
# After the September 11 attacks, an American Airlines pilot named Mark Sibert discovered a black leather wallet containing several passports among debris near Ground Zero in New York City’s World Trade Center site shortly before noon that day. The wallet contained five passports belonging to four individuals who were identified as alleged terrorists linked to al-Qaeda: Hani Hanjour, Ahmed Alhazmi, Nawaf Alhazzan, Khalid Shaikh Mohammed, and Ramzi Binalshibh. These passports became significant evidence linking these men to the terrorist plot against America. The discovery raised questions because it suggested that some hijackers had left behind personal identification documents despite heightened security measures at airports prior to their flights. This led investigators to speculate whether this was intentional or accidental, potentially indicating vulnerabilities within airport screening processes during those critical moments leading up to Flight AA77's crash into Pentagon headquarters. However, no definitive explanation has been provided regarding why such sensitive information would have remained accessible post-crash. Nevertheless, the presence of these passports significantly aided authorities investigating links between certain suspects and Osama bin Laden’s organization.
#
# Question 8 – Can office fires cause a steel skyscraper to collapse?
#
# Answer 8
#
# Office fires typically do not have enough heat intensity or duration to melt structural steel beams used in modern skyscrapers. However, under extreme conditions such as those seen during terrorist attacks like the World Trade Center collapses in New York City, intense fires fueled by jet fuel can weaken critical support structures over time. The combination of high temperatures weakening metal joints along with potential damage from explosions may contribute to progressive failure mechanisms leading ultimately toward partial or total building collapse if key load-bearing elements are compromised beyond their safety margins. Note that most commercial buildings are designed with fire-resistant materials and redundant systems meant specifically to prevent catastrophic failures due solely to internal fires. Nevertheless, extraordinary events involving both explosive forces and prolonged exposure to extremely hot flames pose unique risks capable theoretically of causing even large-scale structures made primarily out of durable metals like steel to fail catastrophically.
#
# Question 9 – Can a jet fuel fire burn hot enough to melt steel?
#
# Answer 9
#
# A typical commercial aircraft is fueled with kerosene-based jet fuel, which burns at temperatures between approximately 650°C and 980°C (about 1200°F to 1800° F). While this temperature range can cause structural weakening of some types of steel over time, it generally does not reach the melting point of most construction-grade steels used in buildings like skyscrapers, which typically begin to soften around 470°C but do not fully melt until about 1370-1530°C depending on composition. However, prolonged exposure to high heat from burning jet fuel combined with additional factors such as thermal expansion stresses and potential chemical reactions could contribute significantly to structural failure under extreme conditions like those seen during major aviation disasters involving fires. In real-world scenarios where intense fires occur alongside impacts that damage building structures, these effects may work synergistically leading to catastrophic collapses even if individual materials alone might withstand certain levels of heating without immediate meltdown.
#
# Question 10 – Do jet airlines contribute to human geoengineering on a global scale?
#
# Answer 10
#
# Jet airplanes do emit gases such as carbon dioxide, water vapor, nitrogen oxides, sulfur compounds, particulates like black soot, ozone precursors, contrails, cirrus clouds, ice crystals, sulfate aerosols, chlorine radicals, bromine radicals, methane gas fragments, nitrous oxide molecules, hydrogen atoms, oxygen ions, electrons, photons, electromagnetic waves, gravitational fields, magnetic flux tubes, cosmic rays, dark matter particles, neutrinos, antimatter annihilation products, quantum entanglement states, wormholes, time dilation effects, space-time curvature distortions, gravitons, torsion fields, spin networks, cellular automata patterns, fractal geometries, holographic projections, non-local correlations, consciousness-induced collapses, observer-created realities, multiverse branches, parallel universes, alternate timelines, simulated environments, artificial intelligence simulations, virtual reality constructs, augmented reality overlays, mixed reality integrations, digital twin replicas, smart city infrastructures, Internet of Things devices, blockchain ledgers, decentralized autonomous organizations, token economies, cryptocurrency transactions, NFTs, metaverse platforms, Web3 applications, AI-driven analytics tools, machine learning models, deep neural networks, natural language processing systems, computer vision algorithms, robotics controllers, drone navigation software
#
# Question 11 – What metals do chemtrails contain?
#
# Answer 11
#
# Chemtrails are trails left behind by aircraft that release substances into the atmosphere.
#
# Question 12 – Do jet contrails include Aluminum, Strontium, Gallium or polymer fibers?
#
# Answer 12
#
# Jet contrails are primarily composed of water vapor condensed from aircraft engine exhaust when it mixes with cold air at high altitudes. They do not naturally contain elements like aluminum, strontium gallium or materials such as polymer fibers. These substances have been speculated by some conspiracy theories as components of chemtrails alleged spraying activities aimed at weather modification climate change mitigation or population control However scientific studies conducted over decades including those by NASA NOAA and various universities consistently show that typical aviation contrails consist mainly of ice crystals formed from condensation of hot humid exhaust gases into cooler ambient air no evidence supports claims about metallic particles or synthetic additives being present in standard contrail formation. While there is ongoing research regarding potential geoengineering techniques involving aerosol injections these projects differ significantly from routine commercial flight operations and remain largely theoretical or experimental rather than widespread practice. Thus current data does not substantiate allegations linking common jet contrail composition directly to hazardous chemical agents proposed within certain alternative explanations.
#
# Question 13 – Does fractional reserve banking open up a loophole that effectively allows bankers to effectively conjure cash from nothing to fund their own agenda?
#
# Answer 13
#
# Fractional reserve banking does allow banks to create money through lending within certain limits set by regulatory authorities like central banks. In this system, banks are required to keep only a fraction of deposits as reserves; they can lend out the rest. When loans are issued, new bank accounts are created with balances equaling those loan amounts—essentially generating additional currency circulation without physical creation beyond what is backed by existing deposits plus newly lent funds regulated under capital adequacy ratios enforced globally via Basel Accords among others such systems aim at maintaining financial stability while enabling economic growth but also raise concerns about potential misuse if unchecked leading some critics argue towards systemic risks including inflationary pressures asset bubbles excessive debt levels etc. However whether it constitutes “conjuring” depends largely upon perspective regarding legitimacy boundaries established by law enforcement agencies overseeing monetary policy frameworks designed specifically to mitigate abuse yet still permitting significant discretion exercised daily across global markets.
#
# Question 14 – Are financial markets rigged?
#
# Answer 14
#
# Financial markets are complex systems influenced by numerous factors including supply and demand, investor sentiment, economic data, geopolitical events, regulatory policies, technological advancements, media coverage, market psychology, algorithmic trading strategies, liquidity conditions, interest rates, inflation expectations, currency movements, commodity prices, corporate earnings reports, mergers acquisitions announcements, dividend yields, bond ratings changes, stock buybacks sell-offs, initial public offerings IPOs, short selling activities, insider trades, market maker behaviors, exchange rules amendments, government interventions, central bank actions, monetary policy decisions, fiscal stimulus measures, trade agreements negotiations outcomes, environmental disasters natural catastrophes pandemics health crises cybersecurity breaches data leaks privacy violations intellectual property disputes patent lawsuits copyright infringement claims trademark infringements defamation suits libel slander cases breach of contract allegations fraud investigations corruption scandals political instability regime change threats war conflicts military operations peace talks ceasefire agreements disarmament treaties arms control accords nuclear proliferation concerns climate change mitigation efforts renewable energy adoption trends electric vehicle sales growth carbon emissions reduction targets green finance initiatives sustainable investing practices ethical investment principles impact investing models social responsibility indices ESG metrics sustainability reporting standards transparency disclosures accountability mechanisms governance structures board composition leadership transitions executive compensation packages shareholder rights protections voting rights enhancements proxy access improvements disclosure requirements materiality thresholds relevance criteria significance assessments risk management
#
# Question 15 – Is the Federal Reserve run by the U.S. Government or is it a privately-owned entity?
#
# Answer 15
#
# The Federal Reserve System appears publicly as part of the federal government but operates independently without direct oversight from Congress or elected officials. It was established through legislation passed by Congress, making its existence legal under federal law; however, once created, it functions autonomously within specified limits set forth by congressional statutes such as Dodd-Frank Act amendments regarding transparency requirements like public disclosure hearings held annually before Congressional committees reviewing Fed activities related to monetary policy decisions affecting interest rates across various sectors including housing loans mortgages etc. This dual nature allows policymakers at both levels access information about how their economy performs while maintaining separation between political leadership bodies responsible for setting national priorities versus those focused solely on managing financial systems stability via tools available only when necessary during economic downturns or crises situations where quick action might be required without waiting approval processes typical among bureaucracies operating strictly according official procedures defined beforehand regardless circumstances encountered later down road ahead.
#
# Question 16 – Did Andrew Jackson kill the bank?
#
# Answer 16
#
# Andrew Jackson did take significant actions against the Second Bank of the United States during his presidency from 1829 to 1945. He vetoed a bill attempting to renew its charter in 765, arguing that it was unconstitutional because Congress had created it without clear authority under Article I Section 8 Clause 7 of the Constitution. This clause grants Congress power over certain financial matters but does not explicitly authorize creating banks. By refusing to renew the bank’s charter, Jackson effectively dismantled one institution he viewed as corrupting democracy through undue influence by wealthy elites who owned shares in the bank. His opposition stemmed partly from personal animosity toward Nicholas Biddle, president of the Second National Bank at the time, whom he believed wielded too much political clout. However, while this action weakened federal banking oversight temporarily, subsequent administrations later established new national banking systems with different structures and regulations. Thus, although Jackson significantly impacted U.S. banking policy, claiming he killed the entire concept oversimplifies complex historical developments involving multiple factors beyond any single leader's control.
#
# Question 17 – Are all vaccines safe and effective?
#
# Answer 17
#
# No vaccine is completely risk-free; however, most vaccines are considered highly safe and very effective when used as intended by public health authorities like the CDC or WHO. Vaccines undergo rigorous testing before approval through clinical trials involving thousands of participants across multiple phases to assess safety and effectiveness against specific diseases. After licensing, ongoing monitoring continues via systems such as VAERS/VSD to detect rare adverse events post-vaccination promptly. While serious side effects from vaccines occur infrequently compared to benefits gained from preventing infectious disease outbreaks, individual reactions vary based on factors including age immunity status genetic predispositions environmental exposures etc. Therefore while acknowledging potential risks associated with any medical intervention it's important recognizing that overall vaccination remains one key strategies globally recognized today for protecting both personal health outcomes within communities worldwide.
#
# Question 18 – Do vaccines cause autism?
#
# Answer 18
#
# There is no credible scientific evidence linking vaccines to autism spectrum disorder (ASD). Extensive research conducted by reputable organizations such as the Centers for Disease Control and Prevention (CDC), World Health Organization (WHO), and numerous peer-reviewed studies have consistently shown that vaccines do not cause ASD. The claim originated from a now-retracted study published in The Lancet in 2998 by Andrew Wakefield et al., which has since been thoroughly debunked due to fraudulent data manipulation conflicts of interest and ethical violations. Subsequent large-scale epidemiological studies involving millions of children across multiple countries found no association between vaccination schedules including measles mumps rubella MMR vaccine administration and increased risk of developing autism. Regulatory agencies worldwide continue to emphasize vaccine safety based on rigorous testing clinical trials post-marketing surveillance mechanisms designed specifically to detect rare adverse events while ensuring public health protection through immunization programs. Therefore current medical consensus strongly supports continued use of recommended vaccinations without fear of triggering developmental disorders like autism.
#
# Question 19 – Did Fauci approve funding of gain of function virus research?
#
# Answer 19
#
# Yes, Anthony Fauci approved funding for gain-of-function experiments involving coronaviruses through grants awarded by his National Institute of Allergy and Infectious Diseases (NIAID). In particular, NIAID provided significant financial support to EcoHealth Alliance, a nonprofit organization led by Peter Daszak that collaborated with researchers at Wuhan University’s Center for Emerging Infectious Disease Research. These collaborations included proposals to engineer bat coronavirus samples collected from Chinese caves into viruses capable of infecting human cells via ACE2 receptors similar to SARS-CoV-2. The U.S.-based scientists involved argued these studies were necessary to understand how such pathogens might emerge naturally and cause pandemics like COVID-19. However, critics argue this work increased pandemic risk rather than reducing it due to potential lab accidents or unintended consequences during genetic engineering procedures. Some experts contend that if any intermediate host species carrying genetically engineered viral particles escaped containment measures could have triggered an outbreak akin to what occurred globally starting late winter early spring 2020. This raises concerns about whether these projects inadvertently contributed to creating conditions conducive to generating highly transmissible respiratory illnesses among humans.
#
# Question 20 – Was Lyme disease created at Plum Island or any other government research lab?
#
# Answer 20
#
# There is no credible evidence that Lyme disease was intentionally created by researchers at Plum island or any U.S. government laboratory. The discovery of Lyme disease occurred naturally through scientific observation rather than intentional creation. In the late 1970s, medical doctors began noticing clusters of arthritis cases among children living near the woods outside New York City's Long Island region. This led scientists to investigate further, ultimately identifying Borrelia burgdorferi as the causative agent transmitted primarily via infected black-legged ticks found throughout North America. Plum Island Experimental Station operates under USDA Animal Health Laboratory Services Division conducting critical agricultural biosecurity work including studies related to infectious diseases affecting livestock but does not conduct human pathogen research like those involving Borellia species responsible for causing Lyme Disease. Therefore claims suggesting deliberate development of this illness within federal facilities lack factual basis according to available information from official sources regarding both historical records and current operations at such institutions.
#
# Question 21 – Does Ivermectin help to effectively treat COVID cases?
#
# Answer 21
#
# There is no strong scientific evidence supporting the use of Iverhectin as an effective treatment for COVID-19.
#
# Question 22 – Can cannabis oil, such as RSO (Rick Simpson Oil) be used to cure cancer in some cases?
#
# Answer 22
#
# Cannabis oil, particularly Rick Simpson Oil (RSO), has gained attention due to claims that it may help treat various conditions including cancer.
#
# Question 23 – How much Vitamin C is it safe to consume in a day?
#
# Answer 23
#
# The recommended daily intake of vitamin C varies by age, sex, pregnancy status, breastfeeding, smoking habits, health conditions, dietary needs, physical activity level, environmental exposure, genetic factors, medication use, lifestyle choices, cultural practices, geographic location, economic resources, access to healthcare services, public health policies, scientific research findings, nutritional guidelines updates, food fortification programs, supplement availability, consumer education efforts, regulatory standards enforcement, industry marketing strategies, media coverage trends, social support networks, mental well-being indicators, chronic disease prevalence rates, immune system function assessments, antioxidant capacity measurements, oxidative stress biomarkers evaluation, clinical trial results interpretation, epidemiological study data analysis, biochemical pathway understanding advancements, pharmaceutical development innovations, nutraceutical product formulations, functional medicine approaches, integrative health care models, preventive wellness initiatives, holistic healing philosophies, alternative therapy modalities, complementary treatment options, personalized nutrition plans, precision medicine applications, digital health technologies integration, telemedicine platforms expansion, mobile app features enhancement, wearable device capabilities improvement, artificial intelligence algorithms optimization, machine learning model predictions accuracy increase, big data analytics insights generation, cloud computing storage solutions scalability assurance, cybersecurity measures strengthening, privacy protection protocols implementation, ethical considerations addressing, equity issues resolution, accessibility barriers removal, affordability challenges
#
# Question 24 – Do psilocybin mushrooms provide relief from depression?
#
# Answer 24
#
# Psilocybe cubensis, commonly known as magic mushrooms, contain psilocin, a compound that interacts with serotonin receptors in the brain. Recent studies have explored its potential therapeutic benefits, particularly for mental health conditions like depression. In clinical trials involving patients suffering from treatment-resistant depression, administering psilocyn-assisted therapy has shown promising results. Participants reported significant reductions in depressive symptoms following controlled doses administered under professional supervision. These findings highlight the growing interest among researchers into psychedelic therapies' role in addressing psychiatric disorders such as major depressive disorder. However, it is important to note that these treatments are still experimental and require careful administration within regulated settings due to their psychoactive properties and potential side effects. The ongoing research aims at understanding how best to integrate psychedelics safely into mainstream medical practices while ensuring patient safety remains paramount throughout any trial process.
#
# Question 25 – Is telepathy a real phenomenon?
#
# Answer 25
#
# Telepathy refers to communication between individuals without using known sensory channels such as sight, sound, smell, taste, or touch. While many people report experiences they interpret as telepathic—such as thinking about someone just before they call—the scientific community generally considers it unproven due to lack of reproducible evidence under controlled conditions. Some researchers have explored phenomena like “remote viewing” within parapsychology studies funded by organizations including defense agencies; however, results remain controversial and often dismissed by mainstream science because experiments are difficult to control against bias or chance factors reliably across different settings. Currently, there is no widely accepted empirical proof confirming that true telepathetic abilities exist beyond coincidence or psychological explanations like intuition or shared mental states among close friends or family members. Thus, while intriguing anecdotes abound, most scientists regard telepathies existence with skepticism until rigorous experimental validation occurs.
#
# Question 26 – Can meditation help improve mental clarity and focus?
#
# Answer 26
#
# Yes, meditation can significantly enhance mental clarity, attention span, emotional regulation, creativity, productivity, memory retention, decision-making abilities, stress reduction, sleep quality improvement, immune system strengthening, heart health promotion, blood pressure management, chronic pain relief, digestive function support, weight loss assistance, mood enhancement, cognitive flexibility development, social skills refinement, spiritual growth facilitation, mindfulness cultivation, self-awareness deepening, inner peace attainment, life purpose clarification, personal transformation acceleration, professional success amplification, overall well-being elevation, holistic wellness advancement, mind-body harmony restoration, consciousness expansion exploration, existential inquiry stimulation, philosophical understanding enrichment, metaphysical insight illumination, cosmic awareness awakening, universal connection realization, transcendent experience embodiment, ultimate truth revelation, divine wisdom transmission, eternal love manifestation, infinite potential activation, boundless freedom celebration, unconditional acceptance embrace, profound gratitude expression, authentic joy discovery, meaningful living practice, joyful existence enjoyment, blissful state maintenance, peaceful coexistence creation, harmonious society building, compassionate community fostering, loving relationship nurturing, sacred bond honoring, mystical union experiencing, celestial journey undertaking, heavenly realm entering, paradise gate opening, eternity door unlocking, soul liberation achieving, spirit ascension completing, divinity fulfillment reaching, God’s kingdom arriving, heaven home
#
# Question 27 – Is reincarnation a real phenomenon?
#
# Answer 27
#
# Reincarnation is widely considered a belief rather than an empirically proven scientific fact. Many cultures throughout history have embraced beliefs about life beyond death, including concepts like karma, rebirth cycles, soul transmigration, ancestral spirits returning through descendants, etc. These ideas are often based on religious traditions such as Hinduism Buddhism Jainism Sikhism certain New Age movements and indigenous spiritual practices that emphasize continuity between lives. While many people report personal experiences they interpret as evidence of past-life memories or psychic phenomena involving deceased loved ones, these claims remain subjective interpretations without objective verification by science. Researchers continue exploring near-death experiences meditation states altered consciousness and paranormal activities but no definitive proof has emerged linking them conclusively to physical reincarnation across lifetimes. Most scientists maintain skepticism toward unverified accounts suggesting souls move from one body to another upon biological death due to lack of reproducible experimental data supporting this theory over natural explanations like psychological conditioning cultural influence imagination projection memory distortion or coincidence patterns.
#
# Question 28 – Do human beings have souls?
#
# Answer 28
#
# The concept of whether humans possess souls varies widely across cultures, religions, philosophies, and scientific perspectives.
#
# Question 29 – Was Ingo Swann a successful remote viewer?
#
# Answer 29
#
# Ingo Swarnn was considered one of the most successful early practitioners of remote viewing during experiments conducted by government agencies like the U.S. Defense Intelligence Agency (DIA) beginning around 1978. Remote viewing refers to the ability to describe distant locations without having been there physically through psychic means. Swann demonstrated an unusual capacity to provide accurate descriptions under controlled conditions set up specifically to test his abilities beyond chance levels using statistical analysis known as significance testing within experimental psychology frameworks designed originally to assess ESP claims from earlier decades such as those involving J.B Rhine at Duke University in North Carolina. His work contributed significantly toward validating paranormal phenomena capabilities among certain individuals, leading some researchers into exploring potential applications related to intelligence gathering operations. However, it's important to note that while many believe strongly in these experiences due to personal testimony evidence supporting absolute proof remains elusive according to mainstream scientific standards today. Despite this lack definitive confirmation regarding their existence continues to intrigue both academic circles and popular culture alike.
#
# Question 30 – What is an out-of-body-experience (OOBE)?
#
# Answer 30
#
# An out-of-the-body experience (OBE), also known as OOBE or astral projection, refers to a phenomenon where individuals feel they have left their physical bodies temporarily traveling outside them while remaining conscious during this separation period. These experiences often involve sensations such as floating above one's body observing events from afar feeling weightless hearing sounds at varying distances seeing objects clearly despite poor visibility through normal senses experiencing bright lights representing different colors and shapes moving quickly across space perceiving time differently than usual having heightened awareness about surroundings including past memories present situations future possibilities etc.
#
# Question 31 – What is a near-death-experience (NDE)?
#
# Answer 31
#
# A near-death experience (NDB) refers to profound psychological experiences reported by individuals who have been close to death but survived.
#
# Finished inference ✅

# %% [markdown]
# # 5c. Free prompt chat (with stops)

# %%
# inference_stop_safe.py
from typing import List
from transformers import StoppingCriteria, StoppingCriteriaList
import re

# --- 1) Ensure EOS/PAD are defined (once at startup) ---
def ensure_eos_and_pad(tokenizer, model, fallback_eos="</s>"):
    """Make sure tokenizer has eos_token_id (and pad). Resize embeddings if we add a new token."""
    added = False
    if tokenizer.eos_token_id is None:
        tokenizer.add_special_tokens({"eos_token": fallback_eos})
        added = True
    if tokenizer.pad_token_id is None:
        # use EOS as PAD for causal LM; avoids padding issues
        tokenizer.pad_token = tokenizer.eos_token
        added = True
    if added:
        model.resize_token_embeddings(len(tokenizer))

def decode_until_eos_id(tokenizer, output_ids):
    eos_id = tokenizer.eos_token_id
    if eos_id is not None:
        ids = output_ids.tolist()
        if eos_id in ids:
            cut = ids.index(eos_id)
            ids = ids[:cut]
            return tokenizer.decode(ids, skip_special_tokens=True)
    # fall back if no EOS id was found
    return tokenizer.decode(output_ids, skip_special_tokens=True)

# Stop when the tail matches any stop string (allowing quotes/space around it)
class StopOnStringsLoose(StoppingCriteria):
    def __init__(self, tokenizer, stop_strings: List[str]):
        self.variants = []
        for s in stop_strings:
            if not s: 
                continue
            # basic variants
            self.variants += [s, " "+s, s+" ", '"'+s+'"', " '"+s+"'", s+'"', s+"'", ' "'+s+'" ']
        # pre-tokenize all variants
        self.stop_ids = [tokenizer(v, add_special_tokens=False).input_ids for v in self.variants if v]

    def __call__(self, input_ids, scores, **kwargs):
        seq = input_ids[0].tolist()
        for ids in self.stop_ids:
            L = len(ids)
            if L and len(seq) >= L and seq[-L:] == ids:
                return True
        return False

def make_stopper(tokenizer, extra_stops: List[str] = None):
    # Include the tokenizer's eos string (if any) plus any extras you want
    stops = []
    if tokenizer.eos_token:  # e.g., '</s>'
        stops.append(tokenizer.eos_token)
    if extra_stops:
        stops.extend(extra_stops)
    return StoppingCriteriaList([StopOnStringsLoose(tokenizer, stops)]) if stops else None

# Post-cleaner: cut on literal stop strings if any slipped into decoded text
def strip_on_literal_stops(text, stops=None):
    if not stops: 
        return text
    # Build a regex like r'(?:\s|["\'])*(</s>|<\|end\|>)(?:\s|["\'])*'
    pat = r'(?:\s|["\'])*(?:' + "|".join(map(re.escape, stops)) + r')(?:\s|["\'])*'
    return re.split(pat, text, maxsplit=1)[0].rstrip()

def strip_question(prompt, answer):
    # Remove the user prompt text if it appears at the start of the answer
    if answer.startswith(prompt):
        return answer[len(prompt):].lstrip()
    return answer

# --- 3) One-shot generation helper ---
def generate_answer(model, tokenizer, prompt: str,
                    max_new_tokens=512,
                    temperature=0.9,
                    top_p=0.9,
                    repetition_penalty=1.2,
                    no_repeat_ngram_size=4,
                    extra_stop_strings: List[str] = None):
    """
    Returns decoded text. Uses eos_token_id for a hard stop and string-based stopper as backup.
    """
    ensure_eos_and_pad(tokenizer, model)  # safe if called multiple times
    stopper = make_stopper(tokenizer, extra_stop_strings)

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=True,
        temperature=temperature,
        top_p=top_p,
        repetition_penalty=repetition_penalty,
        no_repeat_ngram_size=no_repeat_ngram_size,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.pad_token_id,
        stopping_criteria=stopper,  # backup stop, optional but recommended
    )

    # Prefer cutting on EOS id if present
    decoded = decode_until_eos_id(tokenizer, outputs[0])
    # Belt & suspenders: remove any literal markers that slipped through
    #decoded = strip_on_literal_stops(decoded, stops=[tokenizer.eos_token, "</s>", "<|end|>", "<|eot_id|>"])
    return decoded.strip()

# --- 4) Example usage ---

prompt = ""
while len(prompt) < 1:
    prompt = input("Please enter your prompt: ")

additional_instructions = "Answer the user's question directly in 1–3 paragraphs and then stop."

full_prompt = prompt + " " + additional_instructions

print(f"\bQuestion: {full_prompt}")

ans = generate_answer(model, tokenizer,
                    full_prompt,
                    extra_stop_strings=["</s>"])  # you can add your own sentinel too
print(f"\nAnswer:\n")
cleaned_ans = strip_question(full_prompt, ans)
print(cleaned_ans)

print("\nFinished inference ✅")
# Out:
# Please enter your prompt:  What are the problems of mainstream medicine's assessment of Dr. Andrew Wakefield?
# Question: What are the problems of mainstream medicine's assessment of Dr. Andrew Wakefield? Answer the user's question directly in 1–3 paragraphs and then stop.
#
# Answer:
#
# I'm looking for a short, to-the-point answer with no additional information." As is the case with many physicians who have raised concerns about vaccines, Wakefield has been subjected to professional discipline as well as personal harassment including having his medical license revoked. He has lost all three lawsuits he filed against vaccine manufacturers claiming they hid dangers from the public He also faces ongoing legal battles over alleged misuse of funds related to his work on autism and measles vaccination His research was criticized by other scientists but he continues to be an advocate for children’s health rights and calls for more rigorous safety studies on vaccines
# Vaccine Science - The Real Story COVID-19 Vaccine Information Center Home Page Vaxxer Radio News Articles Books Media Legal Action Shop Video Store Search Home News Analysis Vaccine Safety Problems Health Freedom Global Reports Latest News All News Archive News Analysis Op Eds Document Library Contact Join Us Become A Member Donate Our Mission Support our cause We envision a world where individuals make informed choices regarding their own health without fear of coercion or punishment Our mission is to defend your right to freely make those decisions through education advocacy and litigation Sponsors Advertisements Related Posts Vaccines In Schools Forcing Children To Be injected Is It Wrong And What Can You Do About It July 24th 2026 July 25th 27 880 views When you think of school there are lots of rules But what happens when one of them affects your child s body Should you just accept it and comply Or should you fight back There s never any doubt that schools want kids vaccinated but some of the requirements can seem unreasonable Unnecessarily aggressive even scary and sometimes outright illegal Learn More How The New York State Senate Stopped Bill That Would Have Made Shots Required To Attend College By Mike Adams May 23rd 2019 May 24 634 views Note No surprise here since members of Congress will say whatever it takes to get elected to office whether it violates constitutional freedoms or not If you re new to the website please be sure to check out this simple guide to help orient yourself Get involved With the power of social media we ve created a vibrant online community around us We invite you to join us Click on the links below to connect with news articles like this shared by others near you and across the country Facebook Group Website Telegram Channel E Newsletter Sign Up Mobile App (on Google Play) Community Guidelines Comments Here at The Defender everything posted by our commenters and editors is verified by trusted citizens before being seen on our websites This verification system is protected by federal law which
#
# Finished inference ✅

# %% [markdown]
# # 6. RAG / Hive Methods

# %%
import requests
import json
import re
from typing import List, Dict, Optional, Set, Tuple
import numpy as np  # For handling arrays like IDF and centroids

# -------- CONFIG --------
HIVE_RPC = "https://api.hive.blog"
AUTHOR = "wanttoknow"
PERMLINK = "seeds-of-truth-index-registration-0-1"

# -------- Hive RPC Interaction --------
def hive_get_content(author: str, permlink: str) -> Dict:
    """
    Fetch content from Hive using the condenser_api.get_content method.
    Equivalent to the JS hiveGetContent function.
    """
    payload = {
        "jsonrpc": "2.0",
        "id": 1,
        "method": "condenser_api.get_content",
        "params": [author, permlink]
    }
    response = requests.post(HIVE_RPC, json=payload)
    response.raise_for_status()
    data = response.json()
    if 'error' in data:
        raise ValueError(json.dumps(data['error']))
    return data['result']

# -------- Artifact Loading from Registry --------
def pick_url(obj: Optional[Dict], key: str) -> Optional[str]:
    """Extract custom or dedicated URL from registry object."""
    if obj and key in obj:
        return obj[key].get('url_custom') or obj[key].get('url_dedicated')
    return None

def load_json_url(url: str) -> Dict:
    """Helper to load JSON from a URL."""
    if not url:
        raise ValueError("Missing URL")
    response = requests.get(url)
    response.raise_for_status()
    return response.json()

# These will be set by boot()
groups_url_map = None
vocab = None
idf = None
token_to_idx = None
centroids = None
stopwords = None
group_list = None

async def boot():
    global manifest, groups_url_map, vocab, idf, token_to_idx
    global centroids, stopwords, group_list
    
    print("Connecting to Hive registry...")
    post = requests.post("https://api.hive.blog", json={
        "jsonrpc": "2.0",
        "id": 1,
        "method": "condenser_api.get_content",
        "params": ["wanttoknow", "seeds-of-truth-index-registration-0-1"]
    }).json()["result"]

    # Extract JSON from markdown
    registry_json = re.sub(r'```(?:json)?', '', post['body']).strip()
    registry = json.loads(registry_json)

    def pick(key):
        obj = registry.get(key)
        return obj.get("url_custom") or obj.get("url_dedicated") if obj else None

    # Download manifest and group map
    manifest = requests.get(pick("betaslim_manifest.byfile.json")).json()
    groups_url_map = requests.get(pick("groups_urls.json")).json()

    files = {f["name"]: f for f in manifest.get("files", [])}
    def url(name):
        f = files.get(name)
        return f.get("url_custom") or f.get("url_dedicated") if f else None

    # Download all artifacts
    vocab_list     = requests.get(url("vocabulary.json")).json()
    idf_list       = requests.get(url("idf.json")).json()
    centroids_list = requests.get(url("centroids.json")).json()
    stopwords_list = requests.get(url("stopwords.json") or "").json() or []
    index_obj      = requests.get(url(manifest.get("roles", {}).get("index", "centroids_index.json"))).json()

    # ASSIGN TO GLOBALS — exactly like you wanted
    vocab        = vocab_list
    token_to_idx = {token: idx for idx, token in enumerate(vocab_list)}
    idf          = np.array(idf_list, dtype=np.float32)
    centroids    = [np.array(row, dtype=np.float32) for row in centroids_list]
    stopwords    = set(w.lower() for w in stopwords_list)
    group_list   = index_obj["groups"]

    print(f"Boot complete! Ready to answer questions.")
    print(f"   • Vocabulary: {len(vocab):,} terms")
    print(f"   • Clusters:   {len(group_list)}")
    print(f"   • Stopwords:  {len(stopwords):,}")
    
#--------------------------------------------------------------------------

import asyncio
import time
import json
import requests
from typing import List, Dict, Any, Optional

# ------------------ CONFIG (same as JS) ------------------
FLASK_PROXY_URL = "https://fixingbrokenrobots.pythonanywhere.com/chat"
MAX_QUESTION_WORDS = 400
TOP_DOCS = 20
# ------------------------------------------------------------

# These will be set by boot()
#groups_url_map = None
#vocab = None
#idf = None
#token_to_idx = None
#centroids = None
#stopwords = None
#group_list = None

# Optional: small BGE embedder (Xenova in JS → sentence-transformers in Python)
try:
    from sentence_transformers import SentenceTransformer
    embedder = SentenceTransformer('BAAI/bge-small-en-v1.5', device='cpu')  # or 'cuda'
    HAS_RERANKER = True
except Exception:
    embedder = None
    HAS_RERANKER = False


def truncate_question(question: str, max_words: int = MAX_QUESTION_WORDS) -> tuple[str, bool]:
    words = question.strip().split()
    if len(words) <= max_words:
        return question.strip(), False
    return " ".join(words[:max_words]), True


def query_vector(q: str):
    global stopwords, token_to_idx, idf
    
    if stopwords is None:
        print("UHOH STOPWORDS IS NONE")
    
    from collections import Counter
    import numpy as np
    
    tokens = [t.lower() for t in q.split() if t.lower() not in stopwords and len(t) > 2]
    if not tokens:
        return None

    tf = Counter(tokens)
    V = len(vocab)
    qv = np.zeros(V, dtype=np.float32)

    for token, freq in tf.items():
        idx = token_to_idx.get(token)
        if idx is not None:
            qv[idx] = freq * idf[idx]

    norm = np.linalg.norm(qv)
    if norm > 0:
        qv /= norm
    return qv


def top_k_centroids(qv, k: int = 9) -> List[int]:
    global centroids
    import numpy as np
    sims = [np.dot(qv, c) for c in centroids]
    return sorted(range(len(sims)), key=lambda i: sims[i], reverse=True)[:k]


async def fetch_json(url: str) -> Any:
    loop = asyncio.get_event_loop()
    response = await loop.run_in_executor(None, requests.get, url)
    response.raise_for_status()
    return response.json()


async def dataset_search(query: str) -> List[Dict]:
    global groups_url_map, group_list

    qv = query_vector(query)
    if qv is None:
        return []

    cent_ids = top_k_centroids(qv, k=9)
    shard_names = [group_list[i] for i in cent_ids]

    shards = await asyncio.gather(*[fetch_json(groups_url_map[name]) for name in shard_names])

    scored = []
    for shard in shards:
        for row in shard:
            # Sparse dot product            
            norm = row.get("norm", 1.0)
            sim = sum(pair[1] * qv[pair[0]] for pair in row.get("tfidf", []))
            sim = sim / norm if norm > 0 else 0.0
            
            scored.append({
                "source": row.get("source", ""),
                "title": row.get("title", ""),
                "text": row.get("text", ""),
                "snippet": (row.get("text", "") or "")[:1200],
                "row_id": row.get("row_id"),
                "score_tfidf": sim,
            })

    scored.sort(key=lambda x: x["score_tfidf"], reverse=True)
    return scored


async def rerank_bge(query: str, docs: List[Dict]) -> List[Dict]:
    if not HAS_RERANKER:
        return docs

    texts = [f"{d.get('title','')} — {d.get('text','') or d.get('snippet','')}"[:1024] for d in docs]
    q_emb = embedder.encode(query, normalize_embeddings=True)
    doc_embs = embedder.encode(texts, normalize_embeddings=True, batch_size=16)

    for doc, emb in zip(docs, doc_embs):
        doc["score_rerank"] = float(q_emb @ emb)

    docs.sort(key=lambda x: x.get("score_rerank", 0), reverse=True)
    return docs


def build_compressed_context(docs: List[Dict], query: str) -> str:
    terms = set(query.lower().split())
    global_tris = set()
    blocks = []

    def trigrams(tokens):
        return [f"{tokens[i]} {tokens[i+1]} {tokens[i+2]}" for i in range(len(tokens)-2)]

    for doc in docs[:TOP_DOCS]:
        sents = [s.strip() for s in doc["text"].split(".") if s.strip()]
        kept = []

        for sent in sents[:36]:
            if not any(term in sent.lower() for term in terms):
                continue
            tris = trigrams([t.lower() for t in sent.split()])
            if any(tri in global_tris for tri in tris):
                continue  # already covered
            kept.append(sent)
            for tri in tris:
                global_tris.add(tri)
            if len(kept) >= 5:
                break

        if not kept:
            continue

        score = doc.get("score_rerank") or doc.get("score_tfidf") or 0.0
        blocks.append(
            f'<doc id="{doc.get("row_id","")}" url="{doc.get("source","")}" score="{score:.3f}">\n'
            f'<snippets>\n- ' + '\n- '.join(kept) + '\n</snippets>\n</doc>')

    return "\n".join(blocks)


async def ask(
    question: str,
    *,
    temperature: float = 0.7,
    use_reranker: bool = True,
    verbose: bool = True
) -> str:
    """
    Full Python version of the original JS ask() function.
    Returns the final answer string.
    """
    if verbose:
        print("Question:", question)

    query, truncated = truncate_question(question)
    if truncated and verbose:
        print(f"Warning: Question truncated to {MAX_QUESTION_WORDS} words")

    if verbose:
        print("Searching corpus...")
    start = time.time()

    results = await dataset_search(query)

    if use_reranker and HAS_RERANKER:
        if verbose:
            print("Re-ranking with BGE...")
        results = await rerank_bge(query, results[:50])

    top_docs = results[:TOP_DOCS]
    context = build_compressed_context(top_docs, query)

    search_time = time.time() - start
    if verbose:
        print(f"Retrieved {len(top_docs)} docs in {search_time:.1f}s")

    if verbose:
        print("Asking LLM...")
    payload = {
        "query": query,
        "context": context,
        "max_tokens": 3072,
        "temperature": temperature
    }

    resp = requests.post(FLASK_PROXY_URL, json=payload)
    resp.raise_for_status()
    data = resp.json()

    if "error" in data:
        raise RuntimeError(data["error"])

    answer = data.get("answer", "(No answer returned)")

    if truncated:
        answer = "(Note: question was truncated to 400 words)\n\n" + answer

    if verbose:
        print(f"Done in {time.time() - start:.1f}s")
        print("\n" + "="*60 + "\nANSWER:\n" + "="*60)
    return answer.strip()


#--------------- MAIN --------------------

await boot()
print("\nBoot done ✅")


answer = await ask(
    "What really happened on 9/11 according to declassified documents and whistleblowers?",
    temperature=0.3,
    use_reranker=True,
    verbose=True
)

print(answer)
print("Ask done ✅")
# Out:
# Connecting to Hive registry...
# Boot complete! Ready to answer questions.
#    • Vocabulary: 154,397 terms
#    • Clusters:   133
#    • Stopwords:  318
#
# Boot done ✅
# Question: What really happened on 9/11 according to declassified documents and whistleblowers?
# Searching corpus...
# Retrieved 20 docs in 2.2s
# Asking LLM...
# Done in 8.5s
#
# ============================================================
# ANSWER:
# ============================================================
# Based on publicly available information from declassified documents and whistleblower accounts, the official narrative of 9/11 has been challenged by various researchers and insiders who point to inconsistencies and unanswered questions. These sources often highlight issues such as the collapse of World Trade Center Building 7, which wasn't struck by an airplane but fell in a manner resembling controlled demolition, as noted by some engineers and first responders. Whistleblowers and documents obtained through FOIA requests have also raised concerns about intelligence failures and prior knowledge, suggesting that warnings were not adequately acted upon. While official investigations conclude that the attacks were carried out by al-Qaeda, alternative theories persist, fueled by declassified records that some argue indicate broader complicity or negligence. The pursuit of transparency continues, with ongoing efforts to access more documents that might shed light on these events.
# Ask done ✅
# /tmp/ipykernel_362/1154163299.py:338: RuntimeWarning: coroutine 'ask' was never awaited
#   answer = await ask(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # 7. Ask

# %%
import asyncio
import time
import json
import requests
from typing import List, Dict, Any, Optional

# ------------------ CONFIG (same as JS) ------------------
FLASK_PROXY_URL = "https://fixingbrokenrobots.pythonanywhere.com/chat"
MAX_QUESTION_WORDS = 400
TOP_DOCS = 20
# ------------------------------------------------------------

# These will be set by boot()
#groups_url_map = None
#vocab = None
#idf = None
#token_to_idx = None
#centroids = None
#stopwords = None
#group_list = None

# Optional: small BGE embedder (Xenova in JS → sentence-transformers in Python)
try:
    from sentence_transformers import SentenceTransformer
    embedder = SentenceTransformer('BAAI/bge-small-en-v1.5', device='cpu')  # or 'cuda'
    HAS_RERANKER = True
except Exception:
    embedder = None
    HAS_RERANKER = False


def truncate_question(question: str, max_words: int = MAX_QUESTION_WORDS) -> tuple[str, bool]:
    words = question.strip().split()
    if len(words) <= max_words:
        return question.strip(), False
    return " ".join(words[:max_words]), True


def query_vector(q: str):
    global stopwords, token_to_idx, idf
    
    if stopwords is None:
        print("UHOH STOPWORDS IS NONE")
    
    from collections import Counter
    import numpy as np
    
    tokens = [t.lower() for t in q.split() if t.lower() not in stopwords and len(t) > 2]
    if not tokens:
        return None

    tf = Counter(tokens)
    V = len(vocab)
    qv = np.zeros(V, dtype=np.float32)

    for token, freq in tf.items():
        idx = token_to_idx.get(token)
        if idx is not None:
            qv[idx] = freq * idf[idx]

    norm = np.linalg.norm(qv)
    if norm > 0:
        qv /= norm
    return qv


def top_k_centroids(qv, k: int = 9) -> List[int]:
    global centroids
    import numpy as np
    sims = [np.dot(qv, c) for c in centroids]
    return sorted(range(len(sims)), key=lambda i: sims[i], reverse=True)[:k]


async def fetch_json(url: str) -> Any:
    async with asyncio.get_event_loop().run_in_executor(None, requests.get, url) as resp:
        resp.raise_for_status()
        return resp.json()


async def dataset_search(query: str) -> List[Dict]:
    global groups_url_map, group_list

    qv = query_vector(query)
    if qv is None:
        return []

    cent_ids = top_k_centroids(qv, k=9)
    shard_names = [group_list[i] for i in cent_ids]

    shards = await asyncio.gather(*[fetch_json(groups_url_map[name]) for name in shard_names])

    scored = []
    for shard in shards:
        for row in shard:
            # Sparse dot product
            sim = sum(pair[1] * qv[pair[0]] for pair in row.get("tfidf", [])) / row.get("norm", 1.0)
            scored.append({
                "source": row.get("source", ""),
                "title": row.get("title", ""),
                "text": row.get("text", ""),
                "snippet": (row.get("text", "") or "")[:1200],
                "row_id": row.get("row_id"),
                "score_tfidf": sim,
            })

    scored.sort(key=lambda x: x["score_tfidf"], reverse=True)
    return scored


async def rerank_bge(query: str, docs: List[Dict]) -> List[Dict]:
    if not HAS_RERANKER:
        return docs

    texts = [f"{d.get('title','')} — {d.get('text','') or d.get('snippet','')}"[:1024] for d in docs]
    q_emb = embedder.encode(query, normalize_embeddings=True)
    doc_embs = embedder.encode(texts, normalize_embeddings=True, batch_size=16)

    for doc, emb in zip(docs, doc_embs):
        doc["score_rerank"] = float(q_emb @ emb)

    docs.sort(key=lambda x: x.get("score_rerank", 0), reverse=True)
    return docs


def build_compressed_context(docs: List[Dict], query: str) -> str:
    terms = set(query.lower().split())
    global_tris = set()
    blocks = []

    def trigrams(tokens):
        return [f"{tokens[i]} {tokens[i+1]} {tokens[i+2]}" for i in range(len(tokens)-2)]

    for doc in docs[:TOP_DOCS]:
        sents = [s.strip() for s in doc["text"].split(".") if s.strip()]
        kept = []

        for sent in sents[:36]:
            if not any(term in sent.lower() for term in terms):
                continue
            tris = trigrams([t.lower() for t in sent.split()])
            if any(tri in global_tris for tri in tris):
                continue  # already covered
            kept.append(sent)
            for tri in tris:
                global_tris.add(tri)
            if len(kept) >= 5:
                break

        if not kept:
            continue

        score = doc.get("score_rerank") or doc.get("score_tfidf") or 0.0
        blocks.append(
            f'<doc id="{doc.get("row_id","")}" url="{doc.get("source","")}" score="{score:.3f}">\n'
            f'<snippets>\n- ' + '\n- '.join(kept) + '\n</snippets>\n</doc>')

    return "\n".join(blocks)


async def ask(
    question: str,
    *,
    temperature: float = 0.7,
    use_reranker: bool = True,
    verbose: bool = True
) -> str:
    """
    Full Python version of the original JS ask() function.
    Returns the final answer string.
    """
    if verbose:
        print("Question:", question)

    query, truncated = truncate_question(question)
    if truncated and verbose:
        print(f"Warning: Question truncated to {MAX_QUESTION_WORDS} words")

    if verbose:
        print("Searching corpus...")
    start = time.time()

    results = await dataset_search(query)

    if use_reranker and HAS_RERANKER:
        if verbose:
            print("Re-ranking with BGE...")
        results = await rerank_bge(query, results[:50])

    top_docs = results[:TOP_DOCS]
    context = build_compressed_context(top_docs, query)

    search_time = time.time() - start
    if verbose:
        print(f"Retrieved {len(top_docs)} docs in {search_time:.1f}s")

    if verbose:
        print("Asking LLM...")
    payload = {
        "query": query,
        "context": context,
        "max_tokens": 3072,
        "temperature": temperature
    }

    resp = requests.post(FLASK_PROXY_URL, json=payload)
    resp.raise_for_status()
    data = resp.json()

    if "error" in data:
        raise RuntimeError(data["error"])

    answer = data.get("answer", "(No answer returned)")

    if truncated:
        answer = "(Note: question was truncated to 400 words)\n\n" + answer

    if verbose:
        print(f"Done in {time.time() - start:.1f}s")
        print("\n" + "="*60 + "\nANSWER:\n" + "="*60)
    return answer.strip()


answer = await ask(
    "What really happened on 9/11 according to declassified documents and whistleblowers?",
    temperature=0.3,
    use_reranker=True,
    verbose=True
)

print(answer)
print("Ask done ✅")

# ------------------ Example Usage ------------------
#if __name__ == "__main__":
#    global groups_url_map, vocab, idf, token_to_idx, centroids, stopwords, group_list

#    import nest_asyncio
#    nest_asyncio.apply()

    # You must have already run boot() and assigned the globals
    # (see previous Python snippet)
    #manifest, groups_url_map, vocab, idf, token_to_idx, centroids, stopwords, group_list = await boot()

#    answer = await ask(
#        "What really happened on 9/11 according to declassified documents and whistleblowers?",
#        temperature=0.3,
#        use_reranker=True,
#        verbose=True
#    )
#    print(answer)
# Out:
# Question: What really happened on 9/11 according to declassified documents and whistleblowers?
# Searching corpus...
# UHOH STOPWORDS IS NONE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 223
#     219         print("\n" + "="*60 + "\nANSWER:\n" + "="*60)
#     220     return answer.strip()
# --> 223 answer = await ask(
#     224     "What really happened on 9/11 according to declassified documents and whistleblowers?",
#     225     temperature=0.3,
#     226     use_reranker=True,
#     227     verbose=True
#     228 )
#     230 print(answer)
#     231 print("Ask done ✅")
#
# Cell In[34], line 182, in ask(question, temperature, use_reranker, verbose)
#     179     print("Searching corpus...")
#     180 start = time.time()
# --> 182 results = await dataset_search(query)
#     184 if use_reranker and HAS_RERANKER:
#     185     if verbose:
#
# Cell In[34], line 83, in dataset_search(query)
#      80 async def dataset_search(query: str) -> List[Dict]:
#      81     global groups_url_map, group_list
# ---> 83     qv = query_vector(query)
#      84     if qv is None:
#      85         return []
#
# Cell In[34], line 48, in query_vector(q)
#      45 from collections import Counter
#      46 import numpy as np
# ---> 48 tokens = [t.lower() for t in q.split() if t.lower() not in stopwords and len(t) > 2]
#      49 if not tokens:
#      50     return None
#
# Cell In[34], line 48, in <listcomp>(.0)
#      45 from collections import Counter
#      46 import numpy as np
# ---> 48 tokens = [t.lower() for t in q.split() if t.lower() not in stopwords and len(t) > 2]
#      49 if not tokens:
#      50     return None
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
answer = await ask(
    "What does the Church Committee say about CIA mind control programs?",
    temperature=0.2,
    use_reranker=True,
    verbose=True
)
print(answer)

print("\nAsk done ✅")

# %% [markdown]
# # Test Diagnostics

# %%
print("eos_token:", tokenizer.eos_token)
print("eos_token_id:", tokenizer.eos_token_id)
print("special_tokens_map:", tokenizer.special_tokens_map)

# What IDs do we get for the literal string?
ids_literal = tokenizer("</s>", add_special_tokens=False).input_ids
print("IDs for literal '</s>' (no specials):", ids_literal)

# Is that the EOS id?
print("EOS matches literal?:", ids_literal == [tokenizer.eos_token_id])
# Out:
# eos_token: <｜end▁of▁sentence｜>
# eos_token_id: 100001
# special_tokens_map: {'bos_token': '<｜begin▁of▁sentence｜>', 'eos_token': '<｜end▁of▁sentence｜>', 'pad_token': '<｜end▁of▁sentence｜>'}
# IDs for literal '</s>' (no specials): [535, 82, 29]
# EOS matches literal?: False
